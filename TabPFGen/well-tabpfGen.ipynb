# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Patch
import seaborn as sns
df = pd.read_excel('few_data_3.xlsx')


df3 = df.drop(['LABEL'],axis=1)
df4 = df['LABEL']

# %%
from tabpfgen import TabPFGen
from tabpfgen.visuals import visualize_classification_results
from sklearn.datasets import load_breast_cancer

# Load data
X= df3
y=df4
sample = 3000
# Initialize generator
generator = TabPFGen(n_sgld_steps=500)

# Generate synthetic data
X_synth, y_synth = generator.generate_classification(
    X, y,
    n_samples=sample,
    balance_classes=True
)
print(X_synth)
# Out:
# Step 0/500
# Step 100/500
# Step 200/500
# Step 300/500
# Step 400/500
# d:\anaconda\envs\tabpfgen\Lib\site-packages\tabpfn\classifier.py:431: UserWarning: Running on CPU with more than 200 samples may be slow.
# Consider using a GPU or the tabpfn-client API: https://github.com/PriorLabs/tabpfn-client
#   check_cpu_warning(self.device, X)
# [[ 3.1907797e+02  2.5249510e+01  2.2639492e+00 ...  3.3108933e+00
#    3.3087933e+00  1.7909496e+01]
#  [ 3.3849661e+02  4.5370907e+01  2.3667428e+00 ...  2.9049618e+00
#    2.9015236e+00  4.2198725e+00]
#  [ 3.4075885e+02  2.2352856e+01  2.2209773e+00 ...  4.9532890e+00
#    4.9514661e+00  2.4519514e+01]
#  ...
#  [ 3.2015567e+02  3.5233932e+01  2.3351748e+00 ...  3.2478836e+00
#    3.2419536e+00  7.8261655e-04]
#  [ 2.9566446e+02  2.3870468e+01  2.3846970e+00 ...  3.7938235e+00
#    3.7884159e+00 -2.2557370e-02]
#  [ 3.3470676e+02  3.3952736e+01  2.3849864e+00 ...  2.8485525e+00
#    2.8544412e+00 -7.1016476e-03]]

# %%
TabPFGen_data  =  pd.concat([pd.DataFrame(X_synth), pd.DataFrame(y_synth)], axis=1, ignore_index=True)
TabPFGen_data  .to_excel('TabPFGen_data'+str(sample)+'.xlsx',index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

def plot_compare(data1, data2, title=None):
    # 全局字体设置
    plt.rcParams["font.family"] = "Arial"
    plt.rcParams["pdf.fonttype"] = 42  # 确保文字可编辑（矢量图）
    
    # 初始化画布尺寸（8cm宽度，3.15英寸）
    fig = plt.figure(figsize=(3.15, 3.15))
    g = sns.JointGrid(height=3.15, ratio=3, space=0.1, marginal_ticks=True)
    
    # 关闭网格和边框
    g.ax_joint.grid(False)
    for spine in g.ax_joint.spines.values():
        spine.set_linewidth(0.5)
    g.ax_joint.tick_params(width=0.5, length=3, labelsize=7)
    
    # 绘制数据
    kwargs = dict(bins=30, alpha=0.4, edgecolor='none')
    sns.histplot(data=data1, x="AC", y="SP", ax=g.ax_joint, color="blue",**kwargs)
    sns.histplot(data=data2, x="AC", y="SP", ax=g.ax_joint, color="red",**kwargs)
    
    # 边缘分布
    sns.histplot(data=data1, x="AC", ax=g.ax_marg_x, color="blue", element="step",**kwargs)
    sns.histplot(data=data2, x="AC", ax=g.ax_marg_x, color="red", element="step",**kwargs)
    sns.histplot(data=data1, y="SP", ax=g.ax_marg_y, color="blue", element="step",**kwargs)
    sns.histplot(data=data2, y="SP", ax=g.ax_marg_y, color="red", element="step",**kwargs)
    
    # 图例和标签
    legend_elements = [Patch(facecolor='blue', label='Original'), Patch(facecolor='red', label='TabPFGen')]
    g.ax_joint.legend(
    handles=legend_elements,
    fontsize=8,
    frameon=False,
    loc='upper left',          # 指定图例的基准点为左上角
    bbox_to_anchor=(1.01, 1.35),  # 将图例向右上方偏移到画布边缘
    borderaxespad=0.1          # 控制图例与画布边界的间距
    )
    g.ax_joint.set_xlabel("AC (us/ft)", fontsize=8)
    g.ax_joint.set_ylabel("SP (mV)", fontsize=8)
    g.ax_joint.set_xlabel("AC (us/ft)", fontsize=8)
    g.ax_joint.set_ylabel("SP (mV)", fontsize=8)
    
    if title:
        g.ax_joint.set_title(title, fontsize=10)
    
    plt.tight_layout(pad=0.5)
    plt.savefig("TabPFGen1000.tiff", dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.close()

# 数据读取与异常处理（保持不变）
try:
    data = pd.read_excel('yanxin-niyan.xlsx')
    df1 = pd.read_excel('TabPFGen_data.xlsx')
    plot_compare(data1=data, data2=df1, title="TabPFGen")
except Exception as e:
    print(f"Error: {e}")
# Out:
# C:\Users\UPC\AppData\Local\Temp\ipykernel_27724\782475646.py:50: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout(pad=0.5)

# %%
# ================= noisy =================

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

def plot_compare(data1, data2, title=None):
    # 全局字体设置
    plt.rcParams["font.family"] = "Arial"
    plt.rcParams["pdf.fonttype"] = 42  # 确保文字可编辑（矢量图）
    
    # 初始化画布尺寸（8cm宽度，3.15英寸）
    fig = plt.figure(figsize=(3.15, 3.15))
    g = sns.JointGrid(height=3.15, ratio=3, space=0.1, marginal_ticks=True)
    
    # 关闭网格和边框
    g.ax_joint.grid(False)
    for spine in g.ax_joint.spines.values():
        spine.set_linewidth(0.5)
    g.ax_joint.tick_params(width=0.5, length=3, labelsize=7)
    
    # 绘制数据
    kwargs = dict(bins=30, alpha=0.4, edgecolor='none')
    sns.histplot(data=data1, x="AC", y="SP", ax=g.ax_joint, color="blue",**kwargs)
    sns.histplot(data=data2, x="AC", y="SP", ax=g.ax_joint, color="red",**kwargs)
    
    # 边缘分布
    sns.histplot(data=data1, x="AC", ax=g.ax_marg_x, color="blue", element="step",**kwargs)
    sns.histplot(data=data2, x="AC", ax=g.ax_marg_x, color="red", element="step",**kwargs)
    sns.histplot(data=data1, y="SP", ax=g.ax_marg_y, color="blue", element="step",**kwargs)
    sns.histplot(data=data2, y="SP", ax=g.ax_marg_y, color="red", element="step",**kwargs)
    
    # 图例和标签
    legend_elements = [Patch(facecolor='blue', label='Original'), Patch(facecolor='red', label='Noisy')]
    g.ax_joint.legend(
    handles=legend_elements,
    fontsize=8,
    frameon=False,
    loc='upper left',          # 指定图例的基准点为左上角
    bbox_to_anchor=(1.01, 1.35),  # 将图例向右上方偏移到画布边缘
    borderaxespad=0.1          # 控制图例与画布边界的间距
    )
    g.ax_joint.set_xlabel("AC", fontsize=8)
    g.ax_joint.set_ylabel("SP", fontsize=8)
    
    if title:
        g.ax_joint.set_title(title, fontsize=10)
    
    plt.tight_layout(pad=0.5)
    plt.savefig("Noisy.tiff", dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.close()

# 数据读取与异常处理（保持不变）
try:
    data = pd.read_excel('yanxin-niyan.xlsx')
    df1 = pd.read_excel('noisy_data.xlsx')
    plot_compare(data1=data, data2=df1, title="Noisy")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: [Errno 2] No such file or directory: 'noisy_data.xlsx'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
seed = 42
# 加载数据集，需要将 file_path 替换为你的实际文件路径
file_path = 'DATASET-(细砂岩为0-泥岩为2-粉砂岩为1).xlsx'
df = pd.read_excel(file_path)

# 设置标签列
y = df['LABEL']

# 删除包含中文字符的列，假设只有`岩性`列是中文字符列，如果还有其他列，可在列表中添加

# 删除标签列，因为已经单独提取出标签
df = df.drop(columns=['LABEL'])

# 按照 7:3 的比例划分数据集，test_size=0.3 表示测试集占 30%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.4, random_state=seed,stratify=y)
print( X_test)
# Out:
#            AC     CNL    DEN     CAL       GR       SP     PE     R25    RMG  \
# 782   272.944  21.949  2.498  23.529   78.466  172.720  2.613   3.891  2.207
# 955   307.549  26.262  2.413  23.085   91.935  179.798  3.126   2.707  2.626
# 395   346.698  30.240  2.293  25.273   70.858  178.852  2.575   4.340  1.748
# 248   325.161  36.613  2.413  22.711   91.123  169.671  2.980   3.249  1.353
# 1163  278.281  21.713  2.261  22.398   58.399  175.458  2.691   2.971  3.839
# ...       ...     ...    ...     ...      ...      ...    ...     ...    ...
# 752   330.965  32.559  2.407  24.923   99.895  177.561  2.518   3.696  1.492
# 48    330.596  36.252  2.117  21.973   70.638  159.039  1.321  12.376  4.840
# 1140  293.244  22.416  2.327  23.428   79.517  177.576  2.966   4.487  3.083
# 333   326.660  41.425  2.222  24.956   98.180  177.454  3.507   2.861  2.412
# 814   287.620  21.330  2.486  23.878  110.807  180.895  2.740   3.546  1.479
#
#           RT    AT90     PORT1
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, precision_score, \
    recall_score, average_precision_score
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
import numpy as np


def tabular_model_test(x_train, y_train, x_test, y_test,
                       model_name='logistic_regression',
                       sample_weight=None, model_params=None, seed=42):
    """适用于表格结构化数据多分类任务，包含二分类、三分类及更多分类"""
    
    # 强制转换为一维标签（处理可能的隐藏维度，如 (n_samples, 1)）
    y_train = y_train.ravel()
    y_test = y_test.ravel()
    
    num_classes = len(np.unique(y_train))
    print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}, num_classes: {num_classes}")

    # 训练模型（代码不变）
    if model_name == 'xgb':
        xgb_params = {
            'eval_metric': 'merror',
            'random_state': seed,
            'num_class': num_classes,
            'n_estimators': 1000,
            'learning_rate': 0.1,
            'objective': 'multi:softmax'
        }
        if model_params is not None:
            xgb_params.update(model_params)
        model = xgb.XGBClassifier(**xgb_params)
        model.fit(x_train, y_train, sample_weight=sample_weight)
    # 其他模型代码不变...

    # 预测（代码不变）
    test_pred = model.predict(x_test)
    test_pred_proba = model.predict_proba(x_test)

    # 计算评估指标（关键修改）
    test_accuracy = accuracy_score(y_test, test_pred)
    test_precision = precision_score(y_test, test_pred, average='weighted')
    test_f1 = f1_score(y_test, test_pred, average='weighted')
    test_recall = recall_score(y_test, test_pred, average='weighted')
    
    # 处理 average_precision_score（统一转独热矩阵）
    y_true_onehot = np.eye(num_classes)[y_test]
    test_ap = average_precision_score(y_true_onehot, test_pred_proba, average='weighted')
    
    # 处理 roc_auc_score（区分二分类和多分类）
    if num_classes == 2:
        # 二分类：使用正类概率（第二列），无需 multi_class 参数
        test_auc = roc_auc_score(y_test, test_pred_proba[:, 1])
    else:
        # 多分类：显式设置 ovr 和加权平均
        test_auc = roc_auc_score(y_test, test_pred_proba, multi_class='ovr', average='weighted')
    
    # 计算混淆矩阵（代码不变）
    test_confusion_matrix = confusion_matrix(y_test, test_pred)

    print(f'Test Accuracy: {test_accuracy}')
    print(f'Test precision: {test_precision}')
    print(f'Test F1: {test_f1}')
    print(f'Test AUC: {test_auc}')
    print(f'Test AP: {test_ap}')
    print('Test Confusion Matrix:')
    print(test_confusion_matrix)

    return test_accuracy, test_precision, test_f1, test_auc, test_ap

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Patch
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split
seed = 42
# 加载数据集，需要将 file_path 替换为你的实际文件路径
file_path = 'DATASET-(细砂岩为0-泥岩为2-粉砂岩为1).xlsx'
df = pd.read_excel(file_path)

# 设置标签列
y = df['LABEL']

# 删除包含中文字符的列，假设只有`岩性`列是中文字符列，如果还有其他列，可在列表中添加

# 删除标签列，因为已经单独提取出标签
df = df.drop(columns=['LABEL'])

# 按照 7:3 的比例划分数据集，test_size=0.3 表示测试集占 30%
_, X_test, _, y_test = train_test_split(df, y, test_size=0.4, random_state=seed,stratify=y)


df = pd.read_csv('GReaT\GReaT_samples1_few3500.csv')
df3 = df.drop(['LABEL'],axis=1)
df4 = df['LABEL']

results =tabular_model_test(df3, df4, X_test, y_test, model_name='xgb')


# 保存其他指标（如准确率、F1等）
metrics = [results[0], results[1], results[2], results[3], results[4]]
np.savetxt('GReaT\GReaT_metrics_3500.txt', metrics)
# Out:
# C:\Users\UPC\AppData\Local\Temp\ipykernel_27724\3504192551.py:19: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_train = y_train.ravel()
# C:\Users\UPC\AppData\Local\Temp\ipykernel_27724\3504192551.py:20: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_test = y_test.ravel()
# y_train shape: (3500,), y_test shape: (469,), num_classes: 2
# Test Accuracy: 0.9594882729211087
# Test precision: 0.9581603065477252
# Test F1: 0.9583337499792876
# Test AUC: 0.9661897462101856
# Test AP: 0.9837604986084388
# Test Confusion Matrix:
# [[ 44  13]
#  [  6 406]]
